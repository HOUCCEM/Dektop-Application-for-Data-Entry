# %%
import tkinter as tk
from tkinter import ttk
import os
import openpyxl

filepath = r'C:/Users/USER/Desktop/data.xlsx'

workbook = openpyxl.Workbook()
sheet = workbook.active
original_list = ["المال و الطلبات", "أعوان المحضر", "عنوان ممارسة النشاط", "النشاط", "طبيعة المخالفة", "تاريخ الميلاد", " تاريخ اصدار ب ت و", "رقم ب ت و  ", "هوية المخالف", " تاريخ المحضر", "عدد المحضر", "تاريخ الإحالة على وكيل الجمهورية ", "تاريخ الإحالة على الادارة","المصدر", "ع/ر "]
sheet.append(original_list)
workbook.save(filepath)

workbook = openpyxl.load_workbook(filepath)
sheet = workbook.active

def add_data():
    A1 = ar_ent.get()
    A2 = masdar_ent.get()
    A3 = idara_ent.get()
    A4 = wala7_ent.get()
    A5 = idm_ent.get()
    A6 = tariikh_ent.get()
    A7 = mokh_ent.get()
    A8 = btw_ent.get()
    A9 = tariikhbtw_ent.get()
    A10 = milad_ent.get()
    A11 = tabi3_ent.get()
    A12 = nachat_ent.get()
    A13 = adresse_ent.get()
    A14 = a3w_ent.get()
    A15 = talab_ent.get()

    if not os.path.exists(filepath):
        workbook = openpyxl.Workbook()
        sheet = workbook.active
        heading = [
            "المال و الطلبات",
            "أعوان المحضر",
            "عنوان ممارسة النشاط",
            "النشاط",
            "طبيعة المخالفة",
            "تاريخ الميلاد",
            " تاريخ اصدار ب ت و",
            "رقم ب ت و  ",
            "هوية المخالف",
            " تاريخ المحضر",
            "عدد المحضر",
            "تاريخ الإحالة على وكيل الجمهورية ",
            "تاريخ الإحالة على الادارة",
            "المصدر",
            "ع/ر "
        ]

        sheet.append(heading)
        workbook.save(filepath)

    workbook = openpyxl.load_workbook(filepath)
    sheet = workbook.active
    data_row = [A15, A14, A13, A12, A11, A10, A9, A8, A7, A6, A5, A4, A3, A2, A1]
    sheet.append(data_row)
    workbook.save(filepath)

def search_data():
    search_btw = search_ent.get()
    workbook = openpyxl.load_workbook(filepath)
    sheet = workbook.active
    for row in sheet.iter_rows(min_row=2, values_only=True):
        if row[7] == search_btw:
            result_lbl.config(text=f"هوية المخالف: {row[8]} , عدد المحضر :  {row[10]}  ,  طبيعة المخالفة : {row[4]}")
            found = True
            break
    
    if not found:
        result_lbl.config(text="لم يتم العثور على هوية المخالف")

win = tk.Tk()
win.geometry("1350x700+0+0")
win.title("الادارة الجهوية للتجارة و تنمية الصادرات بصفاقس")
title_label = tk.Label(win, text="الادارة الجهوية للتجارة و تنمية الصادرات بصفاقس", font=("Arial", 25, "bold"), border=6, relief=tk.GROOVE)
title_label.pack(side=tk.TOP, fill=tk.X)

detail_frame = tk.LabelFrame(win, text="المعطيات ", font=("Arial", 20), bd=12, relief=tk.GROOVE, bg="lightgrey")
detail_frame.place(x=800, y=50, width=800, height=800)

search_frame = tk.LabelFrame(win, text="بحث", font=("Arial", 20), bd=12, relief=tk.GROOVE, bg="lightgrey")
search_frame.place(x=50, y=50, width=750, height=300)

ar = tk.StringVar()
masdar = tk.StringVar()
idara = tk.StringVar()
wala7 = tk.StringVar()
idm = tk.StringVar()
tariikh = tk.StringVar()
mokh = tk.StringVar()
btw = tk.StringVar()
tariikhbtw = tk.StringVar()
milad = tk.StringVar()
tabi3 = tk.StringVar()
nachat = tk.StringVar()
adresse = tk.StringVar()
a3w = tk.StringVar()
talab = tk.StringVar()
search_btw = tk.StringVar()


ar_lbl = tk.Label(detail_frame, text="ع/ر", font=("Arial", 15), bg="lightgrey")
ar_lbl.grid(row=0, column=0, padx=2, pady=2)
ar_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=ar)
ar_ent.grid(row=0, column=1, padx=2, pady=2)

masdar_lbl = tk.Label(detail_frame, text="المصدر ", font=("Arial", 15), bg="lightgrey")
masdar_lbl.grid(row=1, column=0, padx=2, pady=2)
masdar_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=masdar)
masdar_ent.grid(row=1, column=1, padx=2, pady=2)

idara_lbl = tk.Label(detail_frame, text="تاريخ الإحالة على الادارة", font=("Arial", 15), bg="lightgrey")
idara_lbl.grid(row=2, column=0, padx=2, pady=2)
idara_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=idara)
idara_ent.grid(row=2, column=1, padx=2, pady=2)

wala7_lbl = tk.Label(detail_frame, text="تاريخ الإحالة على وكيل الجمهورية ", font=("Arial", 15), bg="lightgrey")
wala7_lbl.grid(row=3, column=0, padx=2, pady=2)
wala7_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=wala7)
wala7_ent.grid(row=3, column=1, padx=2, pady=2)

idm_lbl = tk.Label(detail_frame, text="عدد المحضر", font=("Arial", 15), bg="lightgrey")
idm_lbl.grid(row=4, column=0, padx=2, pady=2)
idm_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=idm)
idm_ent.grid(row=4, column=1, padx=2, pady=2)

tariikh_lbl = tk.Label(detail_frame, text=" تاريخ المحضر", font=("Arial", 15), bg="lightgrey")
tariikh_lbl.grid(row=5, column=0, padx=2, pady=2)
tariikh_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=tariikh)
tariikh_ent.grid(row=5, column=1, padx=2, pady=2)

mokh_lbl= tk.Label(detail_frame, text="هوية المخالف", font=("Arial", 15), bg="lightgrey")
mokh_lbl.grid(row=6, column=0, padx=2, pady=2)
mokh_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=mokh)
mokh_ent.grid(row=6, column=1, padx=2, pady=2)

btw_lbl= tk.Label(detail_frame, text="رقم ب ت و  ", font=("Arial", 15), bg="lightgrey")
btw_lbl.grid(row=7, column=0, padx=2, pady=2)
btw_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=btw)
btw_ent.grid(row=7, column=1, padx=2, pady=2)

tariikhbtw_lbl= tk.Label(detail_frame, text=" تاريخ اصدار ب ت و", font=("Arial", 15), bg="lightgrey")
tariikhbtw_lbl.grid(row=8, column=0, padx=2, pady=2)
tariikhbtw_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=tariikhbtw)
tariikhbtw_ent.grid(row=8, column=1, padx=2, pady=2)

milad_lbl= tk.Label(detail_frame, text="تاريخ الميلاد", font=("Arial", 15), bg="lightgrey")
milad_lbl.grid(row=9, column=0, padx=2, pady=2)
milad_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=milad)
milad_ent.grid(row=9, column=1, padx=2, pady=2)

tabi3_lbl= tk.Label(detail_frame, text="طبيعة المخالفة", font=("Arial", 15), bg="lightgrey")
tabi3_lbl.grid(row=10, column=0, padx=2, pady=2)
tabi3_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=tabi3)
tabi3_ent.grid(row=10, column=1, padx=2, pady=2)

nachat_lbl= tk.Label(detail_frame, text="النشاط", font=("Arial", 15), bg="lightgrey")
nachat_lbl.grid(row=11, column=0, padx=2, pady=2)
nachat_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=nachat)
nachat_ent.grid(row=11, column=1, padx=2, pady=2)

adresse_lbl= tk.Label(detail_frame, text="عنوان ممارسة النشاط ", font=("Arial", 15), bg="lightgrey")
adresse_lbl.grid(row=12, column=0, padx=2, pady=2)
adresse_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=adresse)
adresse_ent.grid(row=12, column=1, padx=2, pady=2)

a3w_lbl= tk.Label(detail_frame, text="أعوان المحضر", font=("Arial", 15), bg="lightgrey")
a3w_lbl.grid(row=13, column=0, padx=2, pady=2)
a3w_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=a3w)
a3w_ent.grid(row=13, column=1, padx=2, pady=2)

talab_lbl= tk.Label(detail_frame, text="المال و الطلبات", font=("Arial", 15), bg="lightgrey")
talab_lbl.grid(row=14, column=0, padx=2, pady=2)
talab_ent = tk.Entry(detail_frame, bd=7, font=("arial", 15), textvariable=talab)
talab_ent.grid(row=14, column=1, padx=2, pady=2)


search_lbl = tk.Label(search_frame, text="رقم ب ت و  ", font=("Arial", 15), bg="lightgrey")
search_lbl.grid(row=0, column=0, padx=2, pady=2)
search_ent = tk.Entry(search_frame, bd=7, font=("arial", 15), textvariable=search_btw)
search_ent.grid(row=0, column=1, padx=2, pady=2)

search_btn = tk.Button(search_frame, text="بحث", bd=7, command=search_data, font=("Arial", 13), width=20)
search_btn.grid(row=1, columnspan=2, pady=2)

result_lbl = tk.Label(search_frame, text="", font=("Arial", 15), bg="lightgrey")
result_lbl.grid(row=2, columnspan=2, pady=2)

btn_frame = tk.Frame(bg="lightgrey", bd=10, relief=tk.GROOVE)
btn_frame.place(x=675, y=732, height=84)

add_btn = tk.Button(btn_frame, bg="lightgrey", text="أضف", bd=7, command=add_data, font=("Arial", 13), width=20)
add_btn.grid(row=0, column=0, padx=20, pady=2)

win.mainloop()
